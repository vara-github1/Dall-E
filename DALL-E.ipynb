# %% [markdown]
# # **DALL-E**

# %% [markdown]
# DALL·E is like a magic art machine. You tell it what you want, and it makes pictures for you. It learned how to do this by looking at lots of words and pictures, so it's really good at it. You can ask it to make realistic pictures or even completely new ones, and it will do its best to give you what you want.

# %%
pip install openai
# Out:
# ...
#   Obtaining dependency information for openai from https://files.pythonhosted.org/packages/1e/9f/385c25502f437686e4aa715969e5eaf5c2cb5e5ffa7c5cdd52f3c6ae967a/openai-0.28.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for tqdm from https://files.pythonhosted.org/packages/00/e5/f12a80907d0884e6dff9c16d0c0114d81b8cd07dc3ae54c5e962cc83037e/tqdm-4.66.1-py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ------- -------------------------------- 10.2/57.6 kB ? eta -:--:--
#      --------------------------------- ---- 51.2/57.6 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------- 57.6/57.6 kB 764.0 kB/s eta 0:00:00
# ...
#   Obtaining dependency information for aiohttp from https://files.pythonhosted.org/packages/2e/9f/9c37b01fc6a37c92f139a4cd937a92f03ebbd75379cfd55e85ca1e571643/aiohttp-3.8.6-cp311-cp311-win_amd64.whl.metadata
# ...

# %%
pip install secret
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Obtaining dependency information for boto3>=1.2.3 from https://files.pythonhosted.org/packages/50/58/2324b65441c0f83013d27ad8e4b614688d4dd79237ff43d1488dfcc01f3b/boto3-1.28.64-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for pycryptodome>=3.1 from https://files.pythonhosted.org/packages/87/c4/c979db0914a23541d62c9e4b5e8a30f56a78c6dec8677db6a5327d306be5/pycryptodome-3.19.0-cp35-abi3-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for pytest>=2.8.5 from https://files.pythonhosted.org/packages/df/d0/e192c4275aecabf74faa1aacd75ef700091913236ec78b1a98f62a2412ee/pytest-7.4.2-py3-none-any.whl.metadata
# ...

# %%
# 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

# %%
import os
import openai
import secret
import requests
import getpass


# Enter your OpenAI API private access key here. IMPORTANT - don't share your code online if it contains your access key or anyone will be able to access your openai account
openai.api_key = getpass.getpass("Enter your API Key...")

# %% [markdown]
# # **Generating image**

# %% [markdown]
# In order to generate an image using the DALL·E we can use the openai.Image.create call.

# %% [markdown]
# Crafting clear prompts for OpenAI's DALL·E is crucial for helping the model grasp the context of the task, leading to more precise and imaginative results. Put simply, the more specific and detailed your instructions, the better chance you have of getting the results you want, whether it's for you or your audience.

# %%
response = openai.Image.create(
  prompt= "a chef shark making shrimp.",
  n=1,
  size="256x256"
)

# %% [markdown]
# You can make a new picture from a text idea using the image generation feature. You can choose the size of the image, like 256x256, 512x512, or 1024x1024 pixels. Smaller sizes will be quicker to create. You can ask for 1 to 10 images at once by saying how many you want with the "n" parameter. Remember, making a 256x256 picture is faster than making a 1024x1024 one.

# %%
print(response)
# Out:
# {
#   "created": 1697529898,
#   "data": [
#     {
#       "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-qxFszqjD8J8ak8rTcRfiw69b/user-iruDsfmCTu7KQvBglrrsvxpQ/img-bH4NoDIrBawrreIcE2uQ5RbK.png?st=2023-10-17T07%3A04%3A58Z&se=2023-10-17T09%3A04%3A58Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-10-16T08%3A18%3A25Z&ske=2023-10-17T08%3A18%3A25Z&sks=b&skv=2021-08-06&sig=ECqzYxINJQhzIFSlP%2B3L49fOjrhLrMszVzGJVMk27Fk%3D"
#     }
#   ]
# }

# %% [markdown]
# Upon examining the response, we can identify three primary components: "data," which contains all the generated content, and nested within "data," there's a URL. This URL serves as a direct link to the image produced by the AI. The "creation" section primarily functions as an identification marker. Armed with knowledge about the response structure, we can now isolate and retrieve the specific element we require, which is the URL.

# %%
# extracting URl
image_url = response['data'][0]['url']
print(image_url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-qxFszqjD8J8ak8rTcRfiw69b/user-iruDsfmCTu7KQvBglrrsvxpQ/img-bH4NoDIrBawrreIcE2uQ5RbK.png?st=2023-10-17T07%3A04%3A58Z&se=2023-10-17T09%3A04%3A58Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-10-16T08%3A18%3A25Z&ske=2023-10-17T08%3A18%3A25Z&sks=b&skv=2021-08-06&sig=ECqzYxINJQhzIFSlP%2B3L49fOjrhLrMszVzGJVMk27Fk%3D

# %% [markdown]
# # **Saving our image**

# %% [markdown]
# To save the image inside the URL as a file in our Current working directory.
#
# The first thing we are going to do is import the requests library.
#
# Using the request library we can get the image contents. We will use a handler to write in our new image file image_save.jpg. This code should go below all the code, we have already.

# %%
img_data = requests.get(image_url).content
with open('image_save.jpg', 'wb') as handler:
    handler.write(img_data)

# %% [markdown]
# To open the saved image

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Open the JPG file
image = Image.open('image_save.jpg')

# Display the image using Matplotlib
plt.imshow(image)
plt.axis('off')  # Hide axis labels and ticks
plt.show()

# %% [markdown]
# # **N Parameter**

# %% [markdown]
# You can request 1-10 images at a time using the n parameter.

# %%
response = openai.Image.create(
  prompt="a dog smoking a cigar in a poker room.",
  n=3,  # Set n to 3 to request 3 images.
  size="256x256"
)
image_urls = [result['url'] for result in response['data']]

# %% [markdown]
# Here we got 3 URLs generated. What we are going to do is pull the different URL into separate variables and generate files to save the URL.

# %%
image_url1 = response['data'][0]['url']
image_url2 = response['data'][1]['url']
image_url3  = response['data'][2]['url']

# %% [markdown]
# Print 3 images Urls

# %%
print(image_url1)
print(image_url2)
print(image_url3)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-qxFszqjD8J8ak8rTcRfiw69b/user-iruDsfmCTu7KQvBglrrsvxpQ/img-8SrGLZL0WdUYa8v0ynQtnspE.png?st=2023-10-17T07%3A05%3A09Z&se=2023-10-17T09%3A05%3A09Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-10-16T22%3A15%3A15Z&ske=2023-10-17T22%3A15%3A15Z&sks=b&skv=2021-08-06&sig=OB9hISjlPUMilXKf7MWtMo4LKb6g1dmLj2JUwsLqkwk%3D
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-qxFszqjD8J8ak8rTcRfiw69b/user-iruDsfmCTu7KQvBglrrsvxpQ/img-jeXkip6N2QrqCcVixwNvxmzO.png?st=2023-10-17T07%3A05%3A09Z&se=2023-10-17T09%3A05%3A09Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-10-16T22%3A15%3A15Z&ske=2023-10-17T22%3A15%3A15Z&sks=b&skv=2021-08-06&sig=GmavlNxmn1CjqoRcnXudUbnQE/4pV0leJRHhTYj6TTY%3D
# ...

# %% [markdown]
# # **Saving N Images**

# %% [markdown]
# Now we have the URL for the 3 images we are going to save them in different files, namely:
# 1. image_name1.jpg
# 2. image_name2.jpg
# 3. image_name3.jpg
#
# We'll save images same as before

# %%
img_data = requests.get(image_url1).content
with open('image_save1.jpg', 'wb') as handler:
    handler.write(img_data)
img_data = requests.get(image_url2).content
with open('image_save2.jpg', 'wb') as handler:
    handler.write(img_data)
img_data = requests.get(image_url3).content
with open('image_save3.jpg', 'wb') as handler:
    handler.write(img_data)

# %% [markdown]
# or you can also use a for loop to save images and shorten your code

# %%
for i, image_url in enumerate([image_url1, image_url2, image_url3], start=1):
    img_data = requests.get(image_url).content
    with open(f'image_save{i}.jpg', 'wb') as handler:
        handler.write(img_data)

# %% [markdown]
# # **Variation with example**

# %% [markdown]
# **Variation**
#
# OpenAI has an image variation endpoint that allows you to generate similar images when given an image as a prompt.
#
# to do that first we will save an image and then try generating similar image from the saved image.

# %%
#this code generates a new image  from a prompt
response = openai.Image.create(
  prompt="digital art of throne room of a magical castle.",
  n=1,
  size="256x256"
)
#from the response generated this puts the url in a separate variable
image_url = response['data'][0]['url']

#using the url, we use the code below to save it as a file
img_data = requests.get(image_url).content
with open('image_ex.png', 'wb') as handler:
    handler.write(img_data)

# %% [markdown]
# now referring to the image we generated and saved above now creating another image using variation (create_variation function)

# %%
response = openai.Image.create_variation(
  image=open("image_ex.png", "rb"),
  n=1,
  size="1024x1024"
)
image_url = response['data'][0]['url']
#using the url, we use the code below to save it as a file
img_data = requests.get(image_url).content
with open('image_ex_var.png', 'wb') as handler:
    handler.write(img_data)

# %% [markdown]
# Original image we created

# %%
#original
image = Image.open('image_ex.png')

# Display the image using Matplotlib
plt.imshow(image)
plt.axis('off')  # Hide axis labels and ticks
plt.show()

# %% [markdown]
# Variation image

# %%
#variation image
image = Image.open('image_ex_var.png')

# Display the image using Matplotlib
plt.imshow(image)
plt.axis('off')  # Hide axis labels and ticks
plt.show()

# %% [markdown]
# Another Example for variation
#
# Let’s try creating an image variation of a dog and a cat.

# %% [markdown]
# 1. First we generate the original image of the dog and cat.

# %%
#this code generates a new image  from a prompt
response = openai.Image.create(
  prompt="dog and a cat.",
  n=1,
  size="512x512"
)
#from the response generated this putS the url in a separate variable
image_url = response['data'][0]['url']

# %% [markdown]
# 2. We save the dog and cat image.

# %%
#using the url, we use the code below to save it as a file
img_data = requests.get(image_url).content
with open('dog.png', 'wb') as handler:
    handler.write(img_data)

# %% [markdown]
# 3. We use the new image to generate a variation of the said image using our new file name we created in the previous step

# %%
response = openai.Image.create_variation(
  image=open("dog.png", "rb"),
  n=1,
  size="512x512"
)
image_url2= response['data'][0]['url']

# %% [markdown]
# 4. Now we have to save our new URL in a different file name.

# %%
img_data = requests.get(image_url2).content
with open('dog_var.png', 'wb') as handler:
    handler.write(img_data)

# %% [markdown]
# Original image we generated

# %%
# Open the JPG file
image = Image.open('dog.png')

# Display the image using Matplotlib
plt.imshow(image)
plt.axis('off')  # Hide axis labels and ticks
plt.show()

# %% [markdown]
# Variation image

# %%
# Open the JPG file
image = Image.open('dog_var.png')

# Display the image using Matplotlib
plt.imshow(image)
plt.axis('off')  # Hide axis labels and ticks
plt.show()

# %% [markdown]
# # **Masking**

# %% [markdown]
# Masking is a technique used in the training process of the model to restrict or control the generation of certain parts of an image.

# %% [markdown]
# For example,

# %%
response = openai.Image.create(
  prompt="a vintage park with a lot of trees and a bench",
  n=1,
  size="512x512"
)

image_url = response['data'][0]['url']

img_data = requests.get(image_url).content
with open('original.png', 'wb') as handler:
    handler.write(img_data)

print(image_url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-qxFszqjD8J8ak8rTcRfiw69b/user-iruDsfmCTu7KQvBglrrsvxpQ/img-lqhwtd2Y2eUZkhGr4FnXqORu.png?st=2023-10-17T07%3A06%3A29Z&se=2023-10-17T09%3A06%3A29Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-10-16T13%3A27%3A21Z&ske=2023-10-17T13%3A27%3A21Z&sks=b&skv=2021-08-06&sig=uTzYW170xV7S6Q7rsXOJg8YTVcm2bHDlfr8ROKK9GRo%3D

# %%
import shutil

def copy_image(source_path, destination_path):
    try:
        shutil.copy2(source_path, destination_path)
        print("Image copied successfully!")
    except IOError as e:
        print(f"An error occurred while copying the image: {e}")

# Example usage
source_image = "original.png"
destination_image = "original-copy.png"
copy_image(source_image, destination_image)
# Out:
# Image copied successfully!

# %% [markdown]
# The purpose of a mask is to define the region of an image that you want to change or apply an effect to, while leaving the rest of the image unchanged.

# %% [markdown]
# writing over our image

# %%
## Load the original image
img = Image.open('original-copy.png')
# Convert the image to RGBA format
img = img.convert('RGBA')

# %%
# Create a new blank image for the mask
mask = img.copy()

# %% [markdown]
# Now for the fun part we simply gonna draw a rectangle box over where the edit should be.

# %%
# Define the region you want to keep in white
from PIL import ImageDraw

bbox = (300,200, 420, 300)
mask_draw = ImageDraw.Draw(mask)
mask_draw.rectangle(bbox, fill=255)

# Save the mask
mask.save('masked.png')

# %%
image = Image.open('masked.png')

# Display the image using Matplotlib
plt.imshow(image)
plt.axis('off')  # Hide axis labels and ticks
plt.show()

# %% [markdown]
# The bbox variable is a tuple containing four values: (left, top, right, bottom).
# - left is the x-coordinate of the left edge of the bounding box
# - top is the y-coordinate of the top edge of the bounding box
# - right is the x-coordinate of the right edge of the bounding box
# - bottom is the y-coordinate of the bottom edge of the bounding box

# %% [markdown]
# Editing masking area

# %%
response=openai.Image.create_edit(
  image=open("original.png", "rb"),
  mask=open("masked.png", "rb"),
  prompt="a vintage park with a lot of trees and a bench, a tiger walking on the foot path",
  n=1,
  size="512x512"
)
image_url = response['data'][0]['url']
#using the url, we use the code below to save it as a file
img_data = requests.get(image_url).content
with open('edited.png', 'wb') as handler:
    handler.write(img_data)

# %%
image = Image.open('edited.png')

# Display the image using Matplotlib
plt.imshow(image)
plt.axis('off')  # Hide axis labels and ticks
plt.show()

# %%
response=openai.Image.create_edit(
  image=open("original.png", "rb"),
  mask=open("masked.png", "rb"),
  prompt="a vintage park with a lot of trees and a bench, an old man with his grand child",
  n=1,
  size="512x512"
)
image_url = response['data'][0]['url']
#using the url, we use the code below to save it as a file
img_data = requests.get(image_url).content
with open('edited2.png', 'wb') as handler:
    handler.write(img_data)

# %%
image = Image.open('edited2.png')

# Display the image using Matplotlib
plt.imshow(image)
plt.axis('off')  # Hide axis labels and ticks
plt.show()

# %% [markdown]
# # **Chaining**

# %% [markdown]
# Chaining API calls provides us with the ability to produce a series of images in a sequential order using a sequence of prompts.

# %% [markdown]
# it's just like comics and manga you read

# %%
# Set the prompts
prompts = ["dog eating food in from his bowl", "dog laying on bed upside down", "dog cuddling his human"]

# Generate and save the images
for i, prompt in enumerate(prompts):
    response = openai.Image.create(
      prompt=prompt,
      n=1,
      size="256x256"
    )

    # Get the image URL from the response
    image_url = response['data'][0]['url']

    # Download and save the image
    img_data = requests.get(image_url).content
    with open(f"a_dog_day{i+1}.jpg", 'wb') as handler:
        handler.write(img_data)

# %%
image = Image.open('a_dog_day1.jpg')

# Display the image using Matplotlib
plt.imshow(image)
plt.axis('off')  # Hide axis labels and ticks
plt.show()


image = Image.open('a_dog_day2.jpg')

# Display the image using Matplotlib
plt.imshow(image)
plt.axis('off')  # Hide axis labels and ticks
plt.show()


image = Image.open('a_dog_day3.jpg')

# Display the image using Matplotlib
plt.imshow(image)
plt.axis('off')  # Hide axis labels and ticks
plt.show()

# %% [markdown]
# #**Synchronous Vs Asynchronous**

# %% [markdown]
# In a regular, synchronous program, tasks need to finish one by one before the next one can start. This can be wasteful, especially with tasks involving waiting for things like network responses, where the program just sits idle.
# Async programming lets you do other things while waiting for tasks like network operations to complete, making better use of your time and resources.
# Python's asyncio library makes it easy to write code that can do many things at once using coroutines. It's like juggling multiple tasks, such as handling network connections, without the need for separate threads or processes.

# %% [markdown]
# To measure the execution time of your code, you can use the `time.time()` function to capture the start time before the code execution and the end time after it finishes. Then, calculate the difference between these timestamps to obtain the execution time in seconds. Lastly, print the execution time to observe how long your code took to run.

# %%
import time

start_time = time.time()

# Your existing code here

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# Execution time: 0.0 seconds

# %% [markdown]
# ***Synch Example***
#
#
# Same as we kept doing till now

# %%
import os
import openai
import requests
import secret
import time


# Set the prompts
prompts = ["cat eating food in from his bowl", "cat laying on bed upside down", "cat cuddling his human"]

start_time = time.time()  # Start measuring execution time

# Generate and save the images
for i, prompt in enumerate(prompts):
    try:
        response = openai.Image.create(
            prompt=prompt,
            n=1,
            size="256x256"
        )

        # Get the image URL from the response
        image_url = response['data'][0]['url']

        # Download and save the image
        img_data = requests.get(image_url).content
        with open(f"a_cat_day{i+1}.jpg", 'wb') as handler:
            handler.write(img_data)

    except requests.exceptions.RequestException as e:
        # This will catch any general network error
        print(f"Network error: {e}")

    except openai.api_errors.APIError as e:
        # This will catch any error returned by the OpenAI API
        print(f"API error: {e}")

    except Exception as e:
        # This is a catch-all for any other exceptions
        print(f"Unexpected error: {e}")

end_time = time.time()  # End measuring execution time
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# Execution time: 30.098408699035645 seconds

# %% [markdown]
# ***Asynch Example***
#
# Inorder to make Asynchronous API calls we will use Python’s asyncio and aiohttp libraries.

# %% [markdown]
# 1. The `fetch_and_save_image` function is used to download and save an image from a given URL. It takes a session (aiohttp's ClientSession), a URL, and a file path as parameters. It uses aiohttp's `get()` to make a GET request to the URL and asynchronously reads the response content. Then, it opens a file at the specified path and writes the image data to it.
#
#
# ```
# async def fetch_and_save_image(session, url, path):
#     try:
#         async with session.get(url) as resp:
#             img_data = await resp.read()
#             with open(path, 'wb') as handler:
#                 handler.write(img_data)
#     except Exception as e:
#         print(f"Unexpected error: {e}")
# ```

# %% [markdown]
# 2. The `fetch_image` function sends a request to OpenAI's API to create an image based on the provided prompt. It requires a prompt and an index as input. The function utilizes `openai.Image.create()` to generate an image and retrieves the image URL from the response. It subsequently establishes an aiohttp ClientSession and invokes `fetch_and_save_image()` to download and store the image.
#
#
# ```
# async def fetch_image(prompt, i):
#     try:
#         response = openai.Image.create(
#             prompt=prompt,
#             n=1,
#             size="256x256"
#         )
#
#         # Get the image URL from the response
#         image_url = response['data'][0]['url']
#
#         # Download and save the image
#         async with aiohttp.ClientSession() as session:
#             await fetch_and_save_image(session, image_url, f"robot_dog_journey_{i+1}.jpg")
#     except openai.api_errors.APIError as e:
#         # This will catch any error returned by the OpenAI API
#         print(f"API error: {e}")
#
#     except Exception as e:
#         # This is a catch-all for any other exceptions
#         print(f"Unexpected error: {e}")
# ```

# %% [markdown]
# 3. The `main` function leverages asyncio to create tasks for each prompt, adds them to a list, and concurrently executes them using asyncio.gather(). This approach initiates all tasks simultaneously, rather than one after another, which improves efficiency. It also measures execution time by recording the start and end times, enabling you to calculate how long the tasks took to run.
#
#
#
# ```
# async def main():
#     start_time = time.time()  # Start measuring execution time
#
#     tasks = []
#     for i, prompt in enumerate(prompts):
#         tasks.append(fetch_image(prompt, i))
#
#     await asyncio.gather(*tasks)
#
#     end_time = time.time()  # End measuring execution time
#     execution_time = end_time - start_time
#     print(f"Execution time: {execution_time} seconds")
# ```

# %% [markdown]
# Please note that the openai.Image.create function is a blocking operation and doesn’t support async. The code above assumes that this function is asynchronous, which is not correct. To truly parallelize this, you’d need an async-compatible OpenAI library or use something like Python’s concurrent.futures to run the blocking parts in a separate thread.
#
# To remove the error i used that if not - else block in the end

# %%
import os
import openai
import aiohttp
import asyncio
import secret
import time

# Set the prompts
prompts = ["cat eating food from his bowl", "cat laying on bed upside down", "cat cuddling his human"]

async def fetch_and_save_image(session, url, path):
    try:
        async with session.get(url) as resp:
            img_data = await resp.read()
            with open(path, 'wb') as handler:
                handler.write(img_data)
    except Exception as e:
        print(f"Unexpected error: {e}")

async def fetch_image(prompt, i):
    try:
        response = openai.Image.create(
            prompt=prompt,
            n=1,
            size="256x256"
        )

        # Get the image URL from the response
        image_url = response['data'][0]['url']

        # Download and save the image
        async with aiohttp.ClientSession() as session:
            await fetch_and_save_image(session, image_url, f"a_cat_day{i+1}.jpg")
    except openai.api_errors.APIError as e:
        # This will catch any error returned by the OpenAI API
        print(f"API error: {e}")
    except Exception as e:
        # This is a catch-all for any other exceptions
        print(f"Unexpected error: {e}")

async def main():
    start_time = time.time()  # Start measuring execution time

    tasks = []
    for i, prompt in enumerate(prompts):
        tasks.append(fetch_image(prompt, i))

    await asyncio.gather(*tasks)

    end_time = time.time()  # End measuring execution time
    execution_time = end_time - start_time
    print(f"Execution time: {execution_time} seconds")

if __name__ == "__main__":
    loop = asyncio.get_event_loop()
    if not loop.is_running():
        loop.run_until_complete(main())
    else:
        print("An event loop is already running.")
# Out:
# An event loop is already running.
